# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
#env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726624e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.1614999963901937

# %%
import time
from collections import deque

import matplotlib.pyplot as plt
import numpy as np
import torch
from unityagents import UnityEnvironment


## Define the training function
def ddpg(n_episodes=2000, max_t=1000):
    """Deep Deterministic Policy Gradients (DDPG).
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
    """
    scores = []      
    moving_avg = []  

    ## Perform n_episodes of training
    time_training_start = time.time()
    for i_episode in range(1, n_episodes+1):
        time_episode_start = time.time()
        agent.noise.reset()
        states = env.reset(train_mode=True)[brain_name].vector_observations
        scores_episode = np.zeros(num_agents)           

        for t in range(1, max_t+1):
            
            actions = agent.act(states)                 
            env_info = env.step(actions)[brain_name]    
            rewards = env_info.rewards                  
            next_states = env_info.vector_observations  
            
            for (state, action, reward, next_state) \
                    in zip(states, actions, rewards, next_states):
                agent.step(state, action, reward, next_state)
            
            
            states = next_states
            scores_episode += rewards

        
        scores.append(scores_episode.tolist())
        moving_avg.append(np.mean(scores[-_target_episodes:], axis=0))
        # Calculate the elapsed time
        time_episode = time.time() - time_episode_start
        time_elapsed = time.time() - time_training_start
        time_episode_str = time.strftime('%Mm%Ss', time.gmtime(time_episode))

        ## Print the results for this episode
        print('Episode {:3d} ({})\tScore: {:5.2f} (H: {:5.2f} / L: {:5.2f})\t' \
              'Moving average: {:5.2f} (H: {:5.2f} / L: {:5.2f})' \
              .format(i_episode, time_episode_str, scores_episode.mean(),
                      scores_episode.max(), scores_episode.min(),
                      moving_avg[-1].mean(), moving_avg[-1].max(),
                      moving_avg[-1].min()))

        ## Check if the environment has been solved
        if moving_avg[-1].mean() >= _target_score and i_episode >= _target_episodes:
            time_elapsed_str = time.strftime('%Hh%Mm%Ss', time.gmtime(time_elapsed))
            print('\nEnvironment solved in {:d} episodes!\t' \
                  'Average Score: {:.2f}\tElapsed time: {}'
                  .format(i_episode-_target_episodes, moving_avg[-1].mean(),
                          time_elapsed_str))
            
            ## Save the model along with some training information
            checkpoint = {
                'actor_dict': agent.actor_local.state_dict(),
                'critic_dict': agent.critic_local.state_dict(),
                'ddpg_params': {
                    'batch_size': ddpg_agent._batch_size,
                    'buffer_size': ddpg_agent._buffer_size,
                    'gamma': ddpg_agent._gamma,
                    'lr_actor': ddpg_agent._lr_actor,
                    'lr_critic': ddpg_agent._lr_critic,
                    'tau': ddpg_agent._tau,
                    },
                'episodes': i_episode,
                'elapsed_time': time_elapsed_str,
                'scores': scores,
                'moving_avg': moving_avg,
                }
            print('\nSaving model ...', end=' ')
            torch.save(checkpoint, 'checkpoint.pt')
            print('done.')

            break

    return scores, moving_avg

# %%
import ddpg_agent
from ddpg_agent import Agent

_target_score = 30.0
_target_episodes = 100

# Create the single Agent Environment.
agent = Agent(state_size, action_size, random_seed=0)

# Train the Agent
scores, moving_avg = ddpg()
# Out:
# DDPG Agent hyperparameters:
# 	batch size: 		     128
# 	buffer size: 		  100000
# 	discount / gamma: 	   0.990
# 	actor learning rate: 	   0.001
# 	critic learning rate: 	   0.001
# 	soft update / tau: 	   0.001
# 	noise decay rate: 	   0.999
#
# Actor network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=400, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=4, bias=True)
# )
# Actor network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=400, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=4, bias=True)
# )
# Critic network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=404, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=1, bias=True)
# )
# Critic network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=404, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=1, bias=True)
# )
# Episode   1 (03m30s)	Score:  0.88 (H:  1.70 / L:  0.08)	Moving average:  0.88 (H:  1.70 / L:  0.08)
# Episode   2 (03m21s)	Score:  1.97 (H:  4.00 / L:  0.82)	Moving average:  1.43 (H:  2.34 / L:  0.55)
# Episode   3 (03m23s)	Score:  2.43 (H:  4.91 / L:  0.44)	Moving average:  1.76 (H:  2.48 / L:  0.94)
# Episode   4 (03m24s)	Score:  4.70 (H:  6.86 / L:  1.77)	Moving average:  2.49 (H:  3.03 / L:  1.52)
# Episode   5 (03m25s)	Score:  5.85 (H:  7.26 / L:  2.99)	Moving average:  3.17 (H:  3.63 / L:  1.81)
# Episode   6 (03m26s)	Score:  8.95 (H: 12.12 / L:  4.23)	Moving average:  4.13 (H:  4.95 / L:  2.69)
# Episode   7 (03m25s)	Score: 10.23 (H: 17.86 / L:  5.59)	Moving average:  5.00 (H:  6.50 / L:  3.98)
# Episode   8 (03m26s)	Score:  9.97 (H: 14.59 / L:  6.06)	Moving average:  5.62 (H:  7.51 / L:  4.59)
# Episode   9 (03m26s)	Score:  9.18 (H: 16.52 / L:  4.28)	Moving average:  6.02 (H:  7.81 / L:  5.19)
# Episode  10 (03m24s)	Score:  9.05 (H: 16.17 / L:  4.48)	Moving average:  6.32 (H:  7.66 / L:  5.41)
# Episode  11 (03m25s)	Score:  9.50 (H: 13.99 / L:  4.60)	Moving average:  6.61 (H:  8.07 / L:  5.54)
# Episode  12 (03m25s)	Score: 10.01 (H: 14.49 / L:  5.31)	Moving average:  6.89 (H:  8.49 / L:  5.85)
# Episode  13 (03m23s)	Score: 12.66 (H: 18.89 / L:  7.64)	Moving average:  7.34 (H:  9.09 / L:  6.24)
# Episode  14 (03m27s)	Score: 13.25 (H: 18.23 / L:  6.79)	Moving average:  7.76 (H:  9.74 / L:  6.64)
# Episode  15 (03m23s)	Score: 13.18 (H: 21.51 / L:  8.60)	Moving average:  8.12 (H:  9.72 / L:  7.22)
# Episode  16 (03m24s)	Score: 13.94 (H: 23.84 / L:  5.63)	Moving average:  8.48 (H:  9.99 / L:  7.12)
# Episode  17 (03m27s)	Score: 17.40 (H: 24.03 / L:  8.21)	Moving average:  9.01 (H: 10.48 / L:  7.20)
# Episode  18 (03m27s)	Score: 19.27 (H: 30.12 / L: 10.05)	Moving average:  9.58 (H: 11.57 / L:  7.36)
# Episode  19 (03m26s)	Score: 15.47 (H: 21.89 / L:  9.67)	Moving average:  9.89 (H: 12.06 / L:  7.54)
# Episode  20 (03m25s)	Score: 16.98 (H: 22.97 / L:  9.89)	Moving average: 10.24 (H: 12.41 / L:  7.81)
# Episode  21 (03m27s)	Score: 16.75 (H: 20.88 / L:  8.85)	Moving average: 10.55 (H: 12.79 / L:  8.30)
# Episode  22 (03m25s)	Score: 19.21 (H: 28.20 / L: 13.42)	Moving average: 10.95 (H: 13.16 / L:  8.70)
# Episode  23 (03m25s)	Score: 19.76 (H: 25.84 / L: 13.40)	Moving average: 11.33 (H: 13.27 / L:  9.15)
# Episode  24 (03m24s)	Score: 22.65 (H: 31.55 / L: 15.87)	Moving average: 11.80 (H: 13.42 / L:  9.72)
# Episode  25 (03m23s)	Score: 26.93 (H: 34.05 / L: 17.36)	Moving average: 12.41 (H: 14.02 / L: 10.15)
# Episode  26 (03m23s)	Score: 31.88 (H: 38.92 / L: 25.02)	Moving average: 13.16 (H: 14.45 / L: 10.85)
# Episode  27 (03m22s)	Score: 28.95 (H: 34.44 / L: 20.82)	Moving average: 13.74 (H: 14.80 / L: 11.62)
# Episode  28 (03m22s)	Score: 33.89 (H: 38.75 / L: 27.22)	Moving average: 14.46 (H: 15.36 / L: 12.50)
# Episode  29 (03m24s)	Score: 33.56 (H: 38.89 / L: 27.52)	Moving average: 15.12 (H: 16.02 / L: 13.02)
# Episode  30 (03m23s)	Score: 33.19 (H: 39.51 / L: 23.44)	Moving average: 15.72 (H: 16.48 / L: 13.73)
# Episode  31 (03m22s)	Score: 33.71 (H: 39.21 / L: 20.80)	Moving average: 16.30 (H: 17.18 / L: 14.43)
# Episode  32 (03m20s)	Score: 33.56 (H: 37.97 / L: 20.85)	Moving average: 16.84 (H: 17.82 / L: 15.06)
# Episode  33 (03m19s)	Score: 33.19 (H: 39.46 / L: 24.45)	Moving average: 17.34 (H: 18.30 / L: 15.71)
# Episode  34 (03m19s)	Score: 34.92 (H: 38.48 / L: 26.67)	Moving average: 17.85 (H: 18.85 / L: 16.19)
# Episode  35 (03m21s)	Score: 35.10 (H: 39.21 / L: 24.42)	Moving average: 18.35 (H: 19.30 / L: 16.79)
# Episode  36 (03m22s)	Score: 36.51 (H: 39.67 / L: 31.48)	Moving average: 18.85 (H: 19.83 / L: 17.39)
# Episode  37 (03m20s)	Score: 36.04 (H: 39.40 / L: 30.79)	Moving average: 19.32 (H: 20.30 / L: 17.85)
# Episode  38 (03m20s)	Score: 34.65 (H: 38.65 / L: 28.99)	Moving average: 19.72 (H: 20.57 / L: 18.30)
# Episode  39 (03m15s)	Score: 31.08 (H: 37.23 / L: 18.38)	Moving average: 20.01 (H: 20.91 / L: 18.55)
# Episode  40 (03m21s)	Score: 30.02 (H: 38.33 / L: 17.84)	Moving average: 20.26 (H: 21.26 / L: 19.03)
# Episode  41 (03m21s)	Score: 30.50 (H: 39.00 / L: 20.39)	Moving average: 20.51 (H: 21.55 / L: 19.34)
# Episode  42 (03m21s)	Score: 37.02 (H: 39.25 / L: 34.33)	Moving average: 20.90 (H: 21.86 / L: 19.77)
# Episode  43 (03m21s)	Score: 35.08 (H: 39.47 / L: 25.37)	Moving average: 21.23 (H: 22.11 / L: 20.00)
# Episode  44 (03m20s)	Score: 33.68 (H: 39.09 / L: 17.44)	Moving average: 21.52 (H: 22.34 / L: 20.34)
# Episode  45 (03m20s)	Score: 36.21 (H: 39.18 / L: 31.22)	Moving average: 21.84 (H: 22.68 / L: 20.75)
# Episode  46 (03m19s)	Score: 36.04 (H: 39.56 / L: 31.43)	Moving average: 22.15 (H: 22.89 / L: 21.05)
# Episode  47 (03m21s)	Score: 34.81 (H: 39.54 / L: 24.86)	Moving average: 22.42 (H: 23.16 / L: 21.45)
# Episode  48 (03m21s)	Score: 35.29 (H: 39.25 / L: 28.84)	Moving average: 22.69 (H: 23.47 / L: 21.82)
# Episode  49 (03m18s)	Score: 34.33 (H: 38.61 / L: 27.37)	Moving average: 22.93 (H: 23.69 / L: 21.93)
# Episode  50 (03m18s)	Score: 36.76 (H: 39.16 / L: 31.46)	Moving average: 23.20 (H: 23.97 / L: 22.26)
# Episode  51 (03m18s)	Score: 36.28 (H: 39.59 / L: 26.29)	Moving average: 23.46 (H: 24.27 / L: 22.49)
# Episode  52 (03m17s)	Score: 32.56 (H: 39.11 / L: 15.70)	Moving average: 23.63 (H: 24.48 / L: 22.75)
# Episode  53 (03m18s)	Score: 37.82 (H: 39.66 / L: 33.77)	Moving average: 23.90 (H: 24.77 / L: 22.97)
# Episode  54 (03m19s)	Score: 35.92 (H: 38.62 / L: 31.39)	Moving average: 24.12 (H: 25.00 / L: 23.13)
# Episode  55 (03m19s)	Score: 35.96 (H: 39.60 / L: 28.46)	Moving average: 24.34 (H: 25.25 / L: 23.30)
# Episode  56 (03m19s)	Score: 31.18 (H: 37.92 / L: 23.35)	Moving average: 24.46 (H: 25.40 / L: 23.36)
# Episode  57 (03m19s)	Score: 30.46 (H: 39.47 / L: 21.63)	Moving average: 24.57 (H: 25.59 / L: 23.65)
# Episode  58 (03m22s)	Score: 35.63 (H: 38.94 / L: 30.18)	Moving average: 24.76 (H: 25.78 / L: 23.87)
# Episode  59 (03m22s)	Score: 34.91 (H: 39.27 / L: 29.37)	Moving average: 24.93 (H: 25.86 / L: 24.03)
# Episode  60 (03m19s)	Score: 36.89 (H: 39.31 / L: 27.67)	Moving average: 25.13 (H: 26.07 / L: 24.28)
# Episode  61 (03m20s)	Score: 33.59 (H: 37.67 / L: 27.20)	Moving average: 25.27 (H: 26.09 / L: 24.43)
# Episode  62 (03m20s)	Score: 31.07 (H: 37.95 / L: 23.86)	Moving average: 25.36 (H: 26.06 / L: 24.62)
# Episode  63 (03m20s)	Score: 35.04 (H: 39.09 / L: 28.66)	Moving average: 25.52 (H: 26.18 / L: 24.79)
# Episode  64 (03m20s)	Score: 37.81 (H: 39.61 / L: 34.34)	Moving average: 25.71 (H: 26.39 / L: 25.01)
# Episode  65 (03m21s)	Score: 33.32 (H: 39.29 / L: 27.17)	Moving average: 25.82 (H: 26.44 / L: 25.14)
# Episode  66 (03m21s)	Score: 36.26 (H: 39.57 / L: 31.40)	Moving average: 25.98 (H: 26.60 / L: 25.32)
# Episode  67 (03m21s)	Score: 30.71 (H: 38.58 / L: 18.51)	Moving average: 26.05 (H: 26.72 / L: 25.45)
# Episode  68 (03m20s)	Score: 33.24 (H: 39.64 / L: 26.27)	Moving average: 26.16 (H: 26.83 / L: 25.56)
# Episode  69 (03m21s)	Score: 33.93 (H: 38.12 / L: 26.41)	Moving average: 26.27 (H: 26.89 / L: 25.69)
# Episode  70 (03m20s)	Score: 36.77 (H: 39.50 / L: 33.11)	Moving average: 26.42 (H: 26.98 / L: 25.83)
# Episode  71 (03m22s)	Score: 36.77 (H: 39.51 / L: 31.26)	Moving average: 26.57 (H: 27.10 / L: 26.00)
# Episode  72 (03m21s)	Score: 35.96 (H: 39.51 / L: 30.55)	Moving average: 26.70 (H: 27.26 / L: 26.18)
# Episode  73 (03m21s)	Score: 32.39 (H: 37.22 / L: 29.15)	Moving average: 26.78 (H: 27.35 / L: 26.28)
# Episode  74 (03m21s)	Score: 35.10 (H: 38.65 / L: 30.28)	Moving average: 26.89 (H: 27.46 / L: 26.37)
# Episode  75 (03m20s)	Score: 33.72 (H: 36.84 / L: 28.21)	Moving average: 26.98 (H: 27.51 / L: 26.47)
# Episode  76 (03m20s)	Score: 35.06 (H: 39.46 / L: 29.17)	Moving average: 27.09 (H: 27.57 / L: 26.58)
# Episode  77 (03m20s)	Score: 36.07 (H: 39.44 / L: 29.16)	Moving average: 27.20 (H: 27.71 / L: 26.73)
# Episode  78 (03m19s)	Score: 35.94 (H: 38.67 / L: 31.05)	Moving average: 27.31 (H: 27.75 / L: 26.86)
# Episode  79 (03m19s)	Score: 32.46 (H: 37.38 / L: 27.07)	Moving average: 27.38 (H: 27.82 / L: 26.94)
# Episode  80 (03m19s)	Score: 32.81 (H: 36.21 / L: 29.38)	Moving average: 27.45 (H: 27.87 / L: 27.03)
# Episode  81 (03m18s)	Score: 33.01 (H: 37.89 / L: 30.11)	Moving average: 27.52 (H: 27.90 / L: 27.08)
# Episode  82 (03m19s)	Score: 34.52 (H: 39.08 / L: 27.72)	Moving average: 27.60 (H: 28.03 / L: 27.16)
# Episode  83 (03m20s)	Score: 27.04 (H: 35.39 / L: 19.13)	Moving average: 27.59 (H: 28.06 / L: 27.17)
# Episode  84 (03m19s)	Score: 28.59 (H: 38.71 / L: 18.33)	Moving average: 27.61 (H: 28.09 / L: 27.16)
# Episode  85 (03m19s)	Score: 23.50 (H: 35.81 / L: 13.79)	Moving average: 27.56 (H: 28.05 / L: 27.11)
# Episode  86 (03m19s)	Score: 32.21 (H: 38.63 / L: 22.50)	Moving average: 27.61 (H: 28.12 / L: 27.09)
# Episode  87 (03m19s)	Score: 30.30 (H: 37.39 / L: 22.44)	Moving average: 27.64 (H: 28.12 / L: 27.17)
# Episode  88 (03m20s)	Score: 32.07 (H: 36.04 / L: 26.60)	Moving average: 27.69 (H: 28.18 / L: 27.19)
# Episode  89 (03m20s)	Score: 33.78 (H: 37.67 / L: 27.22)	Moving average: 27.76 (H: 28.29 / L: 27.29)
# Episode  90 (03m19s)	Score: 30.21 (H: 36.05 / L: 23.05)	Moving average: 27.79 (H: 28.35 / L: 27.37)
# Episode  91 (03m19s)	Score: 34.07 (H: 38.70 / L: 30.92)	Moving average: 27.86 (H: 28.42 / L: 27.44)
# Episode  92 (03m19s)	Score: 32.69 (H: 38.91 / L: 25.36)	Moving average: 27.91 (H: 28.50 / L: 27.48)
# Episode  93 (03m20s)	Score: 34.28 (H: 38.68 / L: 28.54)	Moving average: 27.98 (H: 28.58 / L: 27.51)
# Episode  94 (03m19s)	Score: 38.14 (H: 39.60 / L: 35.65)	Moving average: 28.09 (H: 28.68 / L: 27.63)
# Episode  95 (03m19s)	Score: 35.09 (H: 39.51 / L: 26.99)	Moving average: 28.16 (H: 28.73 / L: 27.70)
# Episode  96 (03m17s)	Score: 31.41 (H: 38.35 / L: 20.82)	Moving average: 28.19 (H: 28.82 / L: 27.68)
# Episode  97 (03m18s)	Score: 35.09 (H: 39.54 / L: 31.42)	Moving average: 28.27 (H: 28.89 / L: 27.77)
# Episode  98 (03m20s)	Score: 31.64 (H: 34.92 / L: 26.40)	Moving average: 28.30 (H: 28.92 / L: 27.81)
# Episode  99 (03m17s)	Score: 29.66 (H: 39.18 / L: 22.31)	Moving average: 28.31 (H: 28.86 / L: 27.84)
# Episode 100 (03m17s)	Score: 35.25 (H: 39.55 / L: 28.86)	Moving average: 28.38 (H: 28.90 / L: 27.89)
# Episode 101 (03m16s)	Score: 36.62 (H: 39.60 / L: 30.01)	Moving average: 28.74 (H: 29.27 / L: 28.27)
# Episode 102 (03m17s)	Score: 32.99 (H: 39.01 / L: 25.63)	Moving average: 29.05 (H: 29.52 / L: 28.55)
# Episode 103 (03m17s)	Score: 33.57 (H: 38.96 / L: 26.18)	Moving average: 29.36 (H: 29.86 / L: 28.79)
# Episode 104 (03m15s)	Score: 33.80 (H: 39.45 / L: 28.10)	Moving average: 29.65 (H: 30.13 / L: 29.09)
# Episode 105 (03m17s)	Score: 32.67 (H: 38.61 / L: 25.63)	Moving average: 29.92 (H: 30.43 / L: 29.31)
# Episode 106 (03m16s)	Score: 30.27 (H: 37.30 / L: 19.70)	Moving average: 30.14 (H: 30.65 / L: 29.55)
#
# Environment solved in 6 episodes!	Average Score: 30.14	Elapsed time: 05h55m44s
#
# Saving model ... done.

# %%
import numpy as np


scores_mean = np.mean(scores, axis=1)
moving_avg_mean = np.mean(moving_avg, axis=1)
target = [_target_score] * len(scores) 


fig = plt.figure(figsize=(18,8))
fig.suptitle('Plot of the rewards', fontsize='xx-large')

ax = fig.add_subplot(111)
ax.plot(scores_mean, label='Score', color='Blue')
ax.plot(moving_avg_mean, label='Moving Average',
        color='LightGreen', linewidth=3)
ax.plot(target, linestyle='--', color='LightCoral', linewidth=1 )
ax.text(0, _target_score+1, 'Target', color='LightCoral', fontsize='large')
ax.set_ylabel('Score')
ax.set_xlabel('Episode Number')
ax.legend(fontsize='xx-large', loc='lower right')

plt.show()

# Plot one graph for each one of the 20 Agents, if that is the case
if len(scores[0]) == 20:
    fig, axs = plt.subplots(5, 4, figsize=(15, 20), sharex=True, sharey=True)
    fig.suptitle('Rewards for each one of the agents', fontsize='xx-large')

    axs = axs.flatten()
    for idx, (ax, s, m) in enumerate(zip(axs, np.transpose(scores), np.transpose(moving_avg))):
        ax.plot(s, label='Agent Score', color='DodgerBlue', zorder=2)
        ax.plot(m, label='Agent Moving Avg', color='DarkOrange', zorder=3)
        ax.plot(moving_avg_mean, label='Moving Avg (Total)', color='LightGreen', linewidth=3, alpha=0.655, zorder=1)
        ax.plot(target, linestyle='--', color='LightCoral', linewidth=1, zorder=0)
        ax.text(0, _target_score+1, 'Target', color='LightCoral', fontsize='large')

        ax.set_title('Agent #%d' % (idx+1))
        ax.set_ylabel('Score')
        ax.set_xlabel('Episode #')
        ax.label_outer()
        ax.legend(fontsize='medium')

    plt.show()

# %%
## Reset the environment
try:
    env
except:
    env = UnityEnvironment(file_name='Reacher_20_Linux/Reacher.x86_64')
    brain_name = env.brain_names[0]
    brain = env.brains[brain_name]
    env_info = env.reset(train_mode=False)[brain_name]
    states = env_info.vector_observations
    state_size = states.shape[1]
    action_size = brain.vector_action_space_size
    num_agents = len(env_info.agents)

# %%
## Load the trained model
checkpoint = torch.load('checkpoint.pt', map_location='cpu')
agent = Agent(state_size, action_size, random_seed=0)
agent.actor_local.load_state_dict(checkpoint['actor_dict'])
agent.critic_local.load_state_dict(checkpoint['critic_dict'])
# Out:
# DDPG Agent hyperparameters:
# 	batch size: 		     128
# 	buffer size: 		  100000
# 	discount / gamma: 	   0.990
# 	actor learning rate: 	   0.001
# 	critic learning rate: 	   0.001
# 	soft update / tau: 	   0.001
# 	noise decay rate: 	   0.999
#
# Actor network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=400, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=4, bias=True)
# )
# Actor network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=400, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=4, bias=True)
# )
# Critic network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=404, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=1, bias=True)
# )
# Critic network built: ModuleList(
#   (0): Linear(in_features=33, out_features=400, bias=True)
#   (1): Linear(in_features=404, out_features=300, bias=True)
#   (2): Linear(in_features=300, out_features=1, bias=True)
# )

# %%
scores_episode = np.zeros(num_agents)
for i in range(1000):
    actions = agent.act(states, noise=False)
    env_info = env.step(actions)[brain_name]
    states = env_info.vector_observations
    rewards = env_info.rewards
    scores_episode += rewards

print('Score for this episode: {:.2f}'.format(scores_episode.mean()))

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!
